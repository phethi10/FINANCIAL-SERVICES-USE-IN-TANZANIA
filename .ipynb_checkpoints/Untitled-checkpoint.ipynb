# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# reading csv
dataset= pd.read_csv('training.csv')
dataset.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  Latitude  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4 -4.460442
# 1  1258  40   1   1   3   5   1   1     1     0  ...    4    1    4 -6.176438
# 2   331  18   2   4   6   3   2   1     0     0  ...   -1    1    1 -6.825702
# 3  6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4 -3.372049
# 4  8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4 -7.179645
#
#    Longitude  mobile_money  savings  borrowing  insurance  \
# 0  29.811396             0        0          0          0
# 1  39.244871             1        1          1          0
# 2  37.652798             1        0          0          0
# 3  35.808307             1        0          1          0
# 4  31.039095             1        1          0          1
#
#    mobile_money_classification
# 0                            0
# 1                            3
# 2                            2
# 3                            3
# 4                            3
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Are there any missing observations or columns where the data do not seem valid?

# %%
#missing values
missing_values = dataset.isnull().sum().sum()
print('Number of missing values:',missing_values)
# Out:
# Number of missing values: 0

# %% [markdown]
# ## basic descriptive statistics for the dataset.

# %%
#getting basic descriptive for the data set
dataset.describe()
# Out:
#                 ID           Q1           Q2           Q3           Q4  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean   4742.627291    38.239498     1.559910     1.787426     3.060051
# std    2731.120086    16.332148     0.496433     1.165160     1.557779
# min       1.000000    16.000000     1.000000     1.000000     1.000000
# 25%    2397.250000    25.000000     1.000000     1.000000     2.000000
# 50%    4744.500000    35.000000     2.000000     1.000000     3.000000
# 75%    7105.000000    48.000000     2.000000     3.000000     3.000000
# max    9459.000000   100.000000     2.000000     4.000000     8.000000
#
#                 Q5           Q6           Q7         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# std       1.534257     0.366103     0.489508     0.241472     0.482809  ...
# min       1.000000     1.000000     1.000000     0.000000     0.000000  ...
# 25%       1.000000     2.000000     1.000000     0.000000     0.000000  ...
# 50%       3.000000     2.000000     1.000000     0.000000     1.000000  ...
# 75%       4.000000     2.000000     2.000000     0.000000     1.000000  ...
# max       6.000000     2.000000     2.000000     1.000000     1.000000  ...
#
#                Q17          Q18          Q19     Latitude    Longitude  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean     -0.431914     1.860164     3.163378    -6.034378    35.354029
# std       1.489879     1.351372     1.317691     2.720888     2.899511
# min      -1.000000     1.000000     1.000000   -11.467463    29.639578
# 25%      -1.000000     1.000000     2.000000    -8.275387    32.935429
# 50%      -1.000000     1.000000     4.000000    -6.087854    35.073326
# 75%      -1.000000     4.000000     4.000000    -3.517053    38.351815
# max       5.000000     5.000000     5.000000    -1.084000    40.258744
#
#        mobile_money      savings    borrowing    insurance  \
# count   7094.000000  7094.000000  7094.000000  7094.000000
# mean       0.553989     0.461517     0.432901     0.151255
# std        0.497112     0.498552     0.495512     0.358322
# min        0.000000     0.000000     0.000000     0.000000
# 25%        0.000000     0.000000     0.000000     0.000000
# 50%        1.000000     0.000000     0.000000     0.000000
# 75%        1.000000     1.000000     1.000000     0.000000
# max        1.000000     1.000000     1.000000     1.000000
#
#        mobile_money_classification
# count                  7094.000000
# mean                      1.799267
# std                       1.196955
# min                       0.000000
# 25%                       1.000000
# 50%                       2.000000
# 75%                       3.000000
# max                       3.000000
#
# [8 rows x 37 columns]

# %%
# getting basic description of the data set
summary = dataset.describe()
summary = summary.transpose()
summary.head()
# Out:
#      count         mean          std   min      25%     50%     75%     max
# ID  7094.0  4742.627291  2731.120086   1.0  2397.25  4744.5  7105.0  9459.0
# Q1  7094.0    38.239498    16.332148  16.0    25.00    35.0    48.0   100.0
# Q2  7094.0     1.559910     0.496433   1.0     1.00     2.0     2.0     2.0
# Q3  7094.0     1.787426     1.165160   1.0     1.00     1.0     3.0     4.0
# Q4  7094.0     3.060051     1.557779   1.0     2.00     3.0     3.0     8.0

# %% [markdown]
# ## Naming variables

# %%
#naming variables
age = dataset.Q1 
gender =dataset.Q2,
marital_status =dataset.Q3,
education =dataset.Q4
single_response= dataset.Q5
Land_owners=dataset.Q6
mobile_phone=dataset.Q7
salaries=dataset.Q8_1
mobile_money=dataset.mobile_money
savings=dataset.savings
borrowing=dataset.borrowing
insurance=dataset.insurance
mobile_money_classification=dataset.mobile_money_classification

# %%
dataset.rename(columns={'Q1':'age','Q2':'gender','Q3':'marital_status','Q4':'level_of_education','Q5':'read_out_single_response','Q6':'land_owner',
               'Q7':'mobile_phone_owner','Q8_1':'salaries','Q8_2':'money_from_trading_or_selling','Q8_3':'money_from_providing_services',
               'Q8_4':'piece_work','Q8_5':'rental_income','Q8_6':'interest_from_saving','Q8_7':'pension','Q8_8':'social_welfare_money','Q8_9':'rely_on_someone_else',
               'Q8_10':'dont_get_money','Q8_11':'other','Q9':'who_do_you_work_for','Q10':'what_kind_of_thing_do_you_do','Q11':'what_kind_of_service_do_you_provide',
               'Q12':'have_you_sent_money_to_someone','Q13':'who_did_you_last_send_money_to','Q_14':'recieved_money_in_past_12_months',
               'Q15':'when_last_did_you_recieve_money','Q16':'how_often_did_you_use_money_for_purchases','Q17':'how_do_you_use_mobile_money_for_paying_bills','Q18':'literacy_in_kiswhahili','Q19':'literacy_in_english'}, inplace=True)
dataset.head()
# Out:
#      ID  age   gender marital_status level_of_education  \
# 0  5086   98    males         single             degree
# 1  1258   40  females        married           drop_out
# 2   331   18    males        widowed                NaN
# 3  6729   50  females        married           drop_out
# 4  8671   34  females        married             degree
#
#    read_out_single_response  do_you_personally_own_land  mobile_phone_owner  \
# 0                         1                           2                   2
# 1                         5                           1                   1
# 2                         3                           2                   1
# 3                         1                           1                   1
# 4                         1                           2                   1
#
#   salaries  money_from_trading_or_selling  ...  \
# 0       no                              0  ...
# 1      yes                              0  ...
# 2       no                              0  ...
# 3       no                              0  ...
# 4       no                              1  ...
#
#    how_do_you_use_mobile_money_for_paying_bills  literacy_in_kiswhahili  \
# 0                                            -1                       4
# 1                                             4                       1
# 2                                            -1                       1
# 3                                            -1                       1
# 4                                            -1                       1
#
#    literacy_in_english  Latitude  Longitude  mobile_money  savings  borrowing  \
# 0                    4 -4.460442  29.811396            no       no         no
# 1                    4 -6.176438  39.244871           yes      yes        yes
# 2                    1 -6.825702  37.652798           yes       no         no
# 3                    4 -3.372049  35.808307           yes       no        yes
# 4                    4 -7.179645  31.039095           yes      yes         no
#
#    insurance               mobile_money_classification
# 0        yes                                       NaN
# 1        yes  mobile_money_one_other_financial_service
# 2        yes                         mobiel_money_only
# 3        yes  mobile_money_one_other_financial_service
# 4         no  mobile_money_one_other_financial_service
#
# [5 rows x 37 columns]

# %%
age={'18','34','40','50','98'}
number_to_gender= {1:'females', 2:'males'}
marital_status= {1:'married', 2:'divorced', 3:'single', 4:'widowed'}
level_of_education={1:'degree',2:'diploma',3:'drop_out',4:'no_education'}
mobile_money={0:'no', 1:'yes'}
salaries={0:'no',1:'yes'}
savings={0:'no',1:'yes'}
borrowing={0:'no',1:'yes'}
insurance={0:'yes',1:'no'}
mmc={1:'no_mobile_money',2:'mobiel_money_only',3:'mobile_money_one_other_financial_service'}
land_owners={1:'no',2:'yes'}
dataset.age = dataset.age.map(age)
dataset.gender = dataset.gender.map(number_to_gender)
dataset.marital_status = dataset.marital_status.map(marital_status)
dataset.level_of_education = dataset.level_of_education.map(level_of_education)
dataset.mobile_money=dataset.mobile_money.map(mobile_money)
dataset.salaries=dataset.salaries.map(salaries)
dataset.savings=dataset.savings.map(savings)
dataset.borrowing=dataset.borrowing.map(borrowing)
dataset.insurance=dataset.insurance.map(insurance)
dataset.mobile_money_classification=dataset.mobile_money_classification.map(mmc)
dataset.do_you_personally_own_land=dataset.do_you_personally_own_land.map(land_owners)
dataset.head()
# Out:
#      ID  age gender marital_status level_of_education  \
# 0  5086   98    NaN            NaN                NaN
# 1  1258   40    NaN            NaN                NaN
# 2   331   18    NaN            NaN                NaN
# 3  6729   50    NaN            NaN                NaN
# 4  8671   34    NaN            NaN                NaN
#
#    read_out_single_response do_you_personally_own_land  mobile_phone_owner  \
# 0                         1                        yes                   2
# 1                         5                         no                   1
# 2                         3                        yes                   1
# 3                         1                         no                   1
# 4                         1                        yes                   1
#
#   salaries  money_from_trading_or_selling  ...  \
# 0      NaN                              0  ...
# 1      NaN                              0  ...
# 2      NaN                              0  ...
# 3      NaN                              0  ...
# 4      NaN                              1  ...
#
#    how_do_you_use_mobile_money_for_paying_bills  literacy_in_kiswhahili  \
# 0                                            -1                       4
# 1                                             4                       1
# 2                                            -1                       1
# 3                                            -1                       1
# 4                                            -1                       1
#
#    literacy_in_english  Latitude  Longitude  mobile_money  savings  borrowing  \
# 0                    4 -4.460442  29.811396           NaN      NaN        NaN
# 1                    4 -6.176438  39.244871           NaN      NaN        NaN
# 2                    1 -6.825702  37.652798           NaN      NaN        NaN
# 3                    4 -3.372049  35.808307           NaN      NaN        NaN
# 4                    4 -7.179645  31.039095           NaN      NaN        NaN
#
#    insurance  mobile_money_classification
# 0        NaN                          NaN
# 1        NaN                          NaN
# 2        NaN                          NaN
# 3        NaN                          NaN
# 4        NaN                          NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# ## graphs to visually represent the relationship between financial services accessed (non-mobile, mobile, both) and age, gender, marital status, land ownership and type of income.

# %%
#graph representing financial service with mobile,non-mobile and both.
import matplotlib.pyplot as plt
dataset.mobile_money_classification.value_counts().plot(color='yellow' , kind='bar', figsize=(8, 4), rot=0)
plt.xlabel("Mobile money classification", labelpad=14)
plt.ylabel("financial service", labelpad=14)
plt.title("money class and financial service", y=1.02)
plt.legend()
plt.show()

# %%
##graph representing financial service with both female and male genders.
dataset.gender.value_counts().plot(color='purple', kind='bar' , figsize=(7, 6), rot=0)
plt.xlabel("gender", labelpad=14)
plt.ylabel("financial service", labelpad=14)
plt.title("money class and financial service", y=1.02)
plt.legend()
plt.show()

# %%
##graph representing financial service with marital status.
dataset.marital_status.value_counts().plot(color='orange', kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("Marital status", labelpad=14)
plt.ylabel("financial service", labelpad=14)
plt.title("money class and financial service", y=1.02)
plt.legend()
plt.show()

# %%
 dataset.salaries.value_counts().plot(color='red', kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("salaries", labelpad=14)
plt.ylabel("financial service", labelpad=14)
plt.title("money class and financial service", y=1.02)
plt.legend()
plt.show()

# %%
 dataset.do_you_personally_own_land.value_counts().plot(color='pink', kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("do_you_personally_own_land", labelpad=14)
plt.ylabel("financial service", labelpad=14)
plt.title("money class and financial service", y=1.02)
plt.legend()
plt.show()

# %%
 dataset.age.value_counts().plot(color='black', kind='bar', figsize=(20, 6), rot=0)
plt.xlabel("age", labelpad=14)
plt.ylabel("financial service", labelpad=14)
plt.title("money class and financial service", y=1.02)
plt.legend()
plt.show()

# %%
import folium
# maap = folium.Map(location=[6.3690 , 34.8888], zoom_start=13) 
# display(maap)
# maap.save('index.html')


# tooltip = 'Click me!'

# folium.Marker([29.811396, -4.460442], popup='<i>Mt. Hood Meadows</i>', tooltip=tooltip).add_to(maap)
# folium.Marker([39.244871, -6.176438], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)

maap = folium.Map(
    location=[-6.3690281, 34.8888206],
    zoom_start=15,
)

tooltip = 'Click me!'

folium.Marker([-7.179645, 31.039095], popup='<i>Mt. Hood Meadows</i>', tooltip=tooltip).add_to(maap)
folium.Marker([-6.176438, 39.244871], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
folium.Marker([-6.180251, 39.237294], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
folium.Marker([-8.386770, 39.768192], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
folium.Marker([-4.887248, 29.639578], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
folium.Marker([-1.084000, 31.807186], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
folium.Marker([-11.217201,36.981760], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(maap)
display(maap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-e4560848044f> in <module>
#       2 lat = -6.3728253;
#       3 lon = 34.8924826
# ----> 4 income_type_map = folium.Map(location = [lat, lon], zoom_start = 5)
#       5 marker_cluster = MarkerCluster().add_to(income_type_map)
#       6
#
# NameError: name 'folium' is not defined
