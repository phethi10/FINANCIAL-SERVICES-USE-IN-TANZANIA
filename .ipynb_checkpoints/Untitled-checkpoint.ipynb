# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dataset = pd.read_csv('training.csv')

# %%
dataset.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  Latitude  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4 -4.460442
# 1  1258  40   1   1   3   5   1   1     1     0  ...    4    1    4 -6.176438
# 2   331  18   2   4   6   3   2   1     0     0  ...   -1    1    1 -6.825702
# 3  6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4 -3.372049
# 4  8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4 -7.179645
#
#    Longitude  mobile_money  savings  borrowing  insurance  \
# 0  29.811396             0        0          0          0
# 1  39.244871             1        1          1          0
# 2  37.652798             1        0          0          0
# 3  35.808307             1        0          1          0
# 4  31.039095             1        1          0          1
#
#    mobile_money_classification
# 0                            0
# 1                            3
# 2                            2
# ...

# %%
#check for missing observations
dataset.isnull().sum()
# Out:
# ID                             0
# Q1                             0
# Q2                             0
# Q3                             0
# Q4                             0
# Q5                             0
# Q6                             0
# Q7                             0
# Q8_1                           0
# Q8_2                           0
# Q8_3                           0
# Q8_4                           0
# Q8_5                           0
# Q8_6                           0
# Q8_7                           0
# Q8_8                           0
# Q8_9                           0
# Q8_10                          0
# Q8_11                          0
# Q9                             0
# Q10                            0
# Q11                            0
# Q12                            0
# Q13                            0
# Q14                            0
# Q15                            0
# Q16                            0
# Q17                            0
# ...

# %%
#getting basic descriptive for the data set
dataset.describe()
# Out:
#                 ID           Q1           Q2           Q3           Q4  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean   4742.627291    38.239498     1.559910     1.787426     3.060051
# std    2731.120086    16.332148     0.496433     1.165160     1.557779
# min       1.000000    16.000000     1.000000     1.000000     1.000000
# 25%    2397.250000    25.000000     1.000000     1.000000     2.000000
# 50%    4744.500000    35.000000     2.000000     1.000000     3.000000
# 75%    7105.000000    48.000000     2.000000     3.000000     3.000000
# max    9459.000000   100.000000     2.000000     4.000000     8.000000
#
#                 Q5           Q6           Q7         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# std       1.534257     0.366103     0.489508     0.241472     0.482809  ...
# ...

# %%
#naming variables
age = dataset.Q1 
gender =dataset.Q2,
marital_status =dataset.Q3,
education =dataset.Q4
single_response= dataset.Q5
Land_owners=dataset.Q6
mobile_phone=dataset.Q7
salaries=dataset.Q8_1


print(dataset.Q1)
# Out:
# 0       98
# 1       40
# 2       18
# 3       50
# 4       34
#         ..
# 7089    57
# 7090    32
# 7091    22
# 7092    28
# 7093    78
# Name: Q1, Length: 7094, dtype: int64

# %%
dataset.rename(columns='Q1':'age','Q2':'gender','Q3':'marital_status','Q4':'level_of_education','Q5':,'read_out_single_response','Q6':'land_owner','Q7':'mobile_phone_owner','Q8_1':'salaries','Q8_2':'money_from_trading_or_selling','Q8_3':'money_from_providing_services','Q8_4':'piece_work','Q8_5':'rental_income','Q8_6':'interest_from_saving','Q8_7':'pension','Q8_8':'social_welfare_money','Q8_9':,'rely_on_someone_else','Q8_10':'dont_get_money','Q8_11':'other','Q9':'who_do_you_work_for','Q10':'what_kind_of_thing_do_you_do','Q11':)

# %%
#plot graph to visually represent the relationship between financial services accessed code
import seaborn as sns 
sns.kdeplot(dataset.Q1, shade=False , label='age', color='red',)
plt.title('relationship between financial services accessed')
plt.legend()

# %%
sns.kdeplot(dataset.Q2, shade=False , label='Q1', color='blue',)
plt.title('relationship between financial services accessed')
plt.xlabel('mobile_money_classification')
plt.ylabel('age')
plt.legend()

# %%
import folium
import pandas as pd

country_geo = 'world-countries.json'

dataset = pd.read_csv('training.csv')

dataset.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  Latitude  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4 -4.460442
# 1  1258  40   1   1   3   5   1   1     1     0  ...    4    1    4 -6.176438
# 2   331  18   2   4   6   3   2   1     0     0  ...   -1    1    1 -6.825702
# 3  6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4 -3.372049
# 4  8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4 -7.179645
#
#    Longitude  mobile_money  savings  borrowing  insurance  \
# 0  29.811396             0        0          0          0
# 1  39.244871             1        1          1          0
# 2  37.652798             1        0          0          0
# 3  35.808307             1        0          1          0
# 4  31.039095             1        1          0          1
#
#    mobile_money_classification
# 0                            0
# 1                            3
# 2                            2
# ...

# %%
 
# Setup a folium map at a high-level zoom
map = folium.Map(location=[100, 0], zoom_start=1.5)

# choropleth maps bind Pandas Data Frames and json geometries.
#This allows us to quickly visualize data combinations
map.choropleth(geo_data=country_geo,
             columns=['savngs', 'mobile_money'],
             key_on='feature.id',
             fill_color='YlGnBu', fill_opacity=0.7, line_opacity=0.2,
             legend_name=dataset)


map.save('plot_data.html')
# Import the Folium interactive html file


from IPython.display import HTML
HTML('<iframe src=plot_data.html width=700 height=450></iframe>')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-68-c0b2726051c5> in <module>
#       8              key_on='feature.id',
#       9              fill_color='YlGnBu', fill_opacity=0.7, line_opacity=0.2,
# ---> 10              legend_name=dataset)
#      11
#      12
#
# ~/anaconda3/lib/python3.7/site-packages/folium/folium.py in choropleth(self, *args, **kwargs)
#     416         )
#     417         from folium.features import Choropleth
# --> 418         self.add_child(Choropleth(*args, **kwargs))
#     419
#     420     def keep_in_front(self, *args):
#
# ~/anaconda3/lib/python3.7/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
# ...
